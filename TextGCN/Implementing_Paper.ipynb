# %%
import pandas as po

# %%
train = po.read_csv('Task6_Data.csv')

# %%
train.head()
# Out:
#                                                 text  label
# 0  [ link ] shows a way of graphing the exchange ...      0
# 1  This graph of time versus position is called a...      1
# 2  [ link ] is a Feynman diagram for the exchange...      0
# 3  Feynman diagrams are not only a useful tool fo...      0
# 4  Special names are given to particles that feel...      0

# %%
vocab = []

# %%
with open('corpus_task6_vocab.txt', 'r') as vocab_file:
    #vocab = vocab_file.readlines()
    vocab = [word.split('\n')[0] for word in vocab_file.readlines()]

# %%
len(vocab)
# Out:
# 25866

# %%
import pickle
with open ('word_embeddings_BERT', 'rb') as file:
    word_embeddings = pickle.load(file)

# %%
len(word_embeddings)
# Out:
# 25866

# %%
import torch

# %%
torch.__version__
# Out:
# '1.3.0'
